# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from matplotlib import pyplot as plt


# 画像サイズとディレクトリの設定
img_width, img_height = 150, 150
train_data_dir = 'chest_xray/train'
val_data_dir = 'chest_xray/val'

# エポック数の設定
epoch = 40

# 分類クラス名の設定
classes = ['NORMAL','PNEUMONIA']
nb_classes = len(classes)

# VGG16モデルのロード
vgg_model = VGG16(
        include_top = False,
        weights = 'imagenet',
        input_shape = (img_height, img_width, 3))

# VGG16モデルの下に全結合層を追加
model = Sequential()
model.add(vgg_model)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(nb_classes, activation='softmax'))

# VGG16モデルの上位15層のパラメータを凍結
for layer in vgg_model.layers[:15]:
    layer.trainable = False

model.summary()

# 損失関数は交差エントロピー、最適化手法はSGD
model.compile(
        loss = 'categorical_crossentropy',
        optimizer = SGD(0.001, 0.1),
        metrics = ['accuracy'])

# 学習データのデータ拡張を設定
train_datagen = ImageDataGenerator(
        rescale = 1.0 / 255,
        # shear_range = 0.2,
        zoom_range = 0.1,
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        brightness_range=[0.9, 1.1],
        fill_mode="constant",
        horizontal_flip = True)

# 評価データのデータ拡張を設定
test_datagen = ImageDataGenerator(rescale = 1.0 / 255)

# 学習データのジェネレータを生成
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size = (img_height, img_width),
        classes = classes,
        batch_size = 32,
        class_mode = 'categorical')

# 評価データのジェネレータを生成
val_generator = test_datagen.flow_from_directory(
        val_data_dir,
        target_size = (img_height, img_width),
        classes = classes,
        batch_size = 32,
        class_mode = 'categorical')

# コールバック関数（モデルの保存）の設定
mc_cb = ModelCheckpoint(
        filepath = 'pneumonia_2.h5',
        monitor = 'val_loss',
        verbose = 0,
        save_best_only = True)

# ジェネレータを用いたモデルの学習
history = model.fit(
    train_generator,
    epochs=epoch,
    validation_data = val_generator,
    callbacks = [mc_cb])

# 予測誤差のグラフ化
plt.plot(range(len(history.history['loss'])), history.history['loss'], marker='o', color = 'red', label='loss')
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], marker='v', linestyle='--', color='green', label='val_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='best')
plt.show()

# 予測精度のグラフ化
plt.plot(range(len(history.history['accuracy'])), history.history['accuracy'], marker='o', color = 'red', label='acc')
plt.plot(range(len(history.history['val_accuracy'])), history.history['val_accuracy'], marker='v', linestyle='--', color = 'green', label='val_acc')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(loc='best')
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 16,812,610
# Trainable params: 9,177,346
# Non-trainable params: 7,635,264
# _________________________________________________________________
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Epoch 1/40
# 163/163 [==============================] - 75s 325ms/step - loss: 0.3418 - accuracy: 0.8530 - val_loss: 0.3338 - val_accuracy: 0.8125
# Epoch 2/40
# 163/163 [==============================] - 39s 237ms/step - loss: 0.1791 - accuracy: 0.9298 - val_loss: 0.3645 - val_accuracy: 0.8125
# Epoch 3/40
# 163/163 [==============================] - 59s 363ms/step - loss: 0.1403 - accuracy: 0.9465 - val_loss: 0.3223 - val_accuracy: 0.8125
# Epoch 4/40
# 163/163 [==============================] - 108s 663ms/step - loss: 0.1264 - accuracy: 0.9511 - val_loss: 0.2593 - val_accuracy: 0.8750
# Epoch 5/40
# 163/163 [==============================] - 39s 233ms/step - loss: 0.1221 - accuracy: 0.9534 - val_loss: 0.2122 - val_accuracy: 0.8750
# Epoch 6/40
# 163/163 [==============================] - 36s 218ms/step - loss: 0.1125 - accuracy: 0.9574 - val_loss: 0.1848 - val_accuracy: 0.9375
# Epoch 7/40
# 163/163 [==============================] - 36s 218ms/step - loss: 0.1062 - accuracy: 0.9595 - val_loss: 0.2053 - val_accuracy: 0.8750
# Epoch 8/40
# 163/163 [==============================] - 37s 224ms/step - loss: 0.1061 - accuracy: 0.9615 - val_loss: 0.1584 - val_accuracy: 0.9375
# Epoch 9/40
# 163/163 [==============================] - 38s 234ms/step - loss: 0.1018 - accuracy: 0.9624 - val_loss: 0.1566 - val_accuracy: 0.9375
# Epoch 10/40
# 163/163 [==============================] - 39s 239ms/step - loss: 0.0934 - accuracy: 0.9641 - val_loss: 0.1813 - val_accuracy: 0.8750
# Epoch 11/40
# 163/163 [==============================] - 40s 248ms/step - loss: 0.0943 - accuracy: 0.9672 - val_loss: 0.1611 - val_accuracy: 0.9375
# Epoch 12/40
# 163/163 [==============================] - 41s 248ms/step - loss: 0.0953 - accuracy: 0.9655 - val_loss: 0.1280 - val_accuracy: 1.0000
# Epoch 13/40
# 163/163 [==============================] - 42s 260ms/step - loss: 0.0879 - accuracy: 0.9674 - val_loss: 0.1150 - val_accuracy: 1.0000
# Epoch 14/40
# 163/163 [==============================] - 42s 255ms/step - loss: 0.0901 - accuracy: 0.9666 - val_loss: 0.1263 - val_accuracy: 1.0000
# Epoch 15/40
# 163/163 [==============================] - 42s 256ms/step - loss: 0.0824 - accuracy: 0.9716 - val_loss: 0.1526 - val_accuracy: 0.9375
# Epoch 16/40
# 163/163 [==============================] - 42s 257ms/step - loss: 0.0863 - accuracy: 0.9666 - val_loss: 0.1119 - val_accuracy: 1.0000
# Epoch 17/40
# 163/163 [==============================] - 42s 257ms/step - loss: 0.0794 - accuracy: 0.9699 - val_loss: 0.1421 - val_accuracy: 0.9375
# Epoch 18/40
# 163/163 [==============================] - 42s 259ms/step - loss: 0.0826 - accuracy: 0.9705 - val_loss: 0.1051 - val_accuracy: 1.0000
# Epoch 19/40
# 163/163 [==============================] - 43s 264ms/step - loss: 0.0835 - accuracy: 0.9680 - val_loss: 0.1772 - val_accuracy: 0.8750
# Epoch 20/40
# 163/163 [==============================] - 42s 258ms/step - loss: 0.0851 - accuracy: 0.9688 - val_loss: 0.1656 - val_accuracy: 0.8750
# Epoch 21/40
# 163/163 [==============================] - 41s 251ms/step - loss: 0.0770 - accuracy: 0.9711 - val_loss: 0.1008 - val_accuracy: 1.0000
# Epoch 22/40
# 163/163 [==============================] - 43s 266ms/step - loss: 0.0758 - accuracy: 0.9720 - val_loss: 0.1118 - val_accuracy: 1.0000
# Epoch 23/40
# 163/163 [==============================] - 43s 265ms/step - loss: 0.0730 - accuracy: 0.9730 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 24/40
# 163/163 [==============================] - 44s 267ms/step - loss: 0.0758 - accuracy: 0.9734 - val_loss: 0.0868 - val_accuracy: 1.0000
# Epoch 25/40
# 163/163 [==============================] - 42s 257ms/step - loss: 0.0739 - accuracy: 0.9739 - val_loss: 0.1800 - val_accuracy: 0.8750
# Epoch 26/40
# 163/163 [==============================] - 41s 252ms/step - loss: 0.0746 - accuracy: 0.9726 - val_loss: 0.0921 - val_accuracy: 1.0000
# Epoch 27/40
# 163/163 [==============================] - 44s 269ms/step - loss: 0.0720 - accuracy: 0.9734 - val_loss: 0.1257 - val_accuracy: 1.0000
# Epoch 28/40
# 163/163 [==============================] - 43s 262ms/step - loss: 0.0684 - accuracy: 0.9747 - val_loss: 0.1308 - val_accuracy: 1.0000
# Epoch 29/40
# 163/163 [==============================] - 43s 264ms/step - loss: 0.0720 - accuracy: 0.9724 - val_loss: 0.0906 - val_accuracy: 1.0000
# Epoch 30/40
# 163/163 [==============================] - 42s 259ms/step - loss: 0.0669 - accuracy: 0.9764 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 31/40
# 163/163 [==============================] - 43s 262ms/step - loss: 0.0702 - accuracy: 0.9747 - val_loss: 0.0807 - val_accuracy: 1.0000
# Epoch 32/40
# 163/163 [==============================] - 42s 260ms/step - loss: 0.0682 - accuracy: 0.9741 - val_loss: 0.0744 - val_accuracy: 1.0000
# Epoch 33/40
# 163/163 [==============================] - 42s 260ms/step - loss: 0.0665 - accuracy: 0.9768 - val_loss: 0.1290 - val_accuracy: 1.0000
# Epoch 34/40
# 163/163 [==============================] - 43s 262ms/step - loss: 0.0633 - accuracy: 0.9781 - val_loss: 0.0668 - val_accuracy: 1.0000
# Epoch 35/40
# 163/163 [==============================] - 41s 254ms/step - loss: 0.0635 - accuracy: 0.9776 - val_loss: 0.0738 - val_accuracy: 1.0000
# Epoch 36/40
# 163/163 [==============================] - 41s 251ms/step - loss: 0.0652 - accuracy: 0.9766 - val_loss: 0.1072 - val_accuracy: 1.0000
# Epoch 37/40
# 163/163 [==============================] - 44s 272ms/step - loss: 0.0612 - accuracy: 0.9770 - val_loss: 0.0880 - val_accuracy: 1.0000
# Epoch 38/40
# 163/163 [==============================] - 43s 265ms/step - loss: 0.0582 - accuracy: 0.9780 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 39/40
# 163/163 [==============================] - 41s 252ms/step - loss: 0.0610 - accuracy: 0.9781 - val_loss: 0.1196 - val_accuracy: 1.0000
# Epoch 40/40
# 163/163 [==============================] - 42s 260ms/step - loss: 0.0646 - accuracy: 0.9774 - val_loss: 0.1065 - val_accuracy: 1.0000
